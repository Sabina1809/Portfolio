# %%
name = 'Sabina'
print (name)
# Out:
# Sabina

# %%
name = 'Sabina'
surname = 'Alasheva'
full_name = name + surname
print (full_name)
# Out:
# SabinaAlasheva

# %%
print (name [0])
# Out:
# S

# %%
print (name [5])
# Out:
# a

# %%
print (name [-1])
# Out:
# a

# %%
print (name [:])
# Out:
# Sabina

# %%
print (surname [::-1])
# Out:
# avehsalA

# %%
print (name [3:5]) #start, stop, step
# Out:
# in

# %%
print (name [0:5:2]) #start, stop, step
# Out:
# Sbn

# %%
print (len(name))
# Out:
# 6

# %%
name.upper()
# Out:
# 'SABINA'

# %%
name.lower()
# Out:
# 'sabina'

# %%
name.capitalize()
# Out:
# 'Sabina'

# %%
name.find('i')
# Out:
# 3

# %%
name.count('n')
# Out:
# 1

# %%
name.startswith ('S')
# Out:
# True

# %%
fruits = ['apple', 'banana','mango']
print (friuts)
# Out:
# ['apple', 'banana', 'mango', 'peach', 'peach']

# %%
fruits.append('peach')
fruits
# Out:
# ['apple', 'banana', 'mango', 'peach']

# %%
fruits.extend(['pineapple','lemon'])
fruits
# Out:
# ['apple', 'banana', 'mango', 'peach', 'pineapple', 'lemon']

# %%
fruits.insert(1,'coconut')
fruits
# Out:
# ['apple', 'coconut', 'banana', 'mango', 'peach', 'pineapple', 'lemon']

# %%
fruits.remove('lemon')
fruits
# Out:
# ['apple', 'coconut', 'banana', 'mango', 'peach', 'pineapple']

# %%
fruits.pop(0)
fruits
# Out:
# ['coconut', 'banana', 'mango', 'peach', 'pineapple']

# %%
fruits.reverse()
fruits
# Out:
# ['pineapple', 'peach', 'mango', 'banana', 'coconut']

# %%
fruits.sort()
fruits
# Out:
# ['banana', 'coconut', 'mango', 'peach', 'pineapple']

# %%
new_fruits = fruits [:]
print (new_fruits)
# Out:
# ['banana', 'coconut', 'mango', 'peach', 'pineapple']

# %%
new_fruits = list (fruits)
print (new_fruits)
# Out:
# ['banana', 'coconut', 'mango', 'peach', 'pineapple']

# %%
import copy
new_fruits = copy.copy (fruits)
print(new_fruits)
# Out:
# ['banana', 'coconut', 'mango', 'peach', 'pineapple']

# %%
purse = {'money':12, 'candy':3,'tissues':75}
purse
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
purse = dict(money=12, candy=3,tissues=75)
purse
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
friuts_price = {'apple':20,'banana':10,'mango':30}
friuts_price
# Out:
# {'apple': 20, 'banana': 10, 'mango': 30}

# %%
friuts_price = {'apple':20,'banana':10,'mango':30}
friuts_price.keys()
# Out:
# dict_keys(['apple', 'banana', 'mango'])

# %%
friuts_price = {'apple':20,'banana':10,'mango':30}
friuts_price.values()
# Out:
# dict_values([20, 10, 30])

# %%
friuts_price = {'apple':20,'banana':10,'mango':30}
friuts_price.items()
# Out:
# dict_items([('apple', 20), ('banana', 10), ('mango', 30)])

# %%
purse.update(friuts_price)
purse
# Out:
# {'money': 12,
#  'candy': 3,
#  'tissues': 75,
#  'apple': 20,
#  'banana': 10,
#  'mango': 30}

# %%
result = {**purse, **friuts_price}
result
# Out:
# {'money': 12,
#  'candy': 3,
#  'tissues': 75,
#  'apple': 20,
#  'banana': 10,
#  'mango': 30}

# %%
cars = ('nexia','cobalt','isuzu')
cars
# Out:
# ('nexia', 'cobalt', 'isuzu')

# %%
colors = {'violet','black', 'white'}
colors
# Out:
# {'black', 'violet', 'white'}
