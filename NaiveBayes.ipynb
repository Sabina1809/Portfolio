# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer

# %%
X = ["with money now", "meeting tomorrow","free money prize","share with others"]
y = ["spam","not spam", "spam", "not spam"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

model = MultinomialNB()
model.fit(X,y)

model.predict(vectorizer.transform(['money talks']))
# Out:
# array(['spam'], dtype='<U8')

# %%
X = ["with money now", "meeting tomorrow","free money prize","share with others"]
y = ["spam","not spam", "spam", "not spam"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

model = MultinomialNB()
model.fit(X,y)

model.predict(vectorizer.transform(['sky blue']))
# Out:
# array(['not spam'], dtype='<U8')

# %%
X = ["with money now", "meeting tomorrow","free money prize","share with others"]
y = ["spam","not spam", "spam", "not spam"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

model = MultinomialNB()
model.fit(X,y)

model.predict(vectorizer.transform(['with me']))
# Out:
# array(['not spam'], dtype='<U8')
