# %%
yosh = 20
if yosh > 18:
  print ("Balog‘at yoshiga to‘lgan")
else:
  print ("Balog‘at yoshiga to‘lmagan")
# Out:
# Balog‘at yoshiga to‘lgan

# %%
x = 5
if x > 1 :
  print('More than one')
  if x < 100 :
     print ('Less than 100')
print ('All done')
# Out:
# More than one
# Less than 100
# All done

# %%
x = 5
print ('Before 5')
if x == 5 :
  print ('Is 5')
  print ('Is Still 5')
  print ('Third 5')
# Out:
# Before 5
# Is 5
# Is Still 5
# Third 5

# %%
x = 5
if x < 2:
    print('Small')
elif x < 10:
    print('Medium')
else:
    print('Large')
print('All done')
# Out:
# Medium
# All done

# %%
n = 5
while n > 0:
  print(n)
  n = n - 1
print ('Done')
# Out:
# 5
# 4
# 3
# 2
# 1
# Done

# %%
n = 5
while n > 0:
  print(n)
  n = n - 1
  if n==1:
    break
print ('Done')
# Out:
# 5
# 4
# 3
# 2
# Done

# %%
n = 5
while n > 0:
    print(n)
    n = n - 1
    if n == 3:
     break
print ('Done')
# Out:
# 5
# 4
# Done

# %%
numbers = [5,4,3,2,1]
for n in numbers:
  print (n)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
numbers = [5,4,3,2,1]
for n in numbers:
  print(n+1)
# Out:
# 6
# 5
# 4
# 3
# 2

# %%
my_dict = {'a': 1,'b': 2,'c': 3}
for key, value in my_dict.items():
  print(f"Key: {key}, Value: {value}")
# Out:
# Key: a, Value: 1
# Key: b, Value: 2
# Key: c, Value: 3

# %%
def greetPerson():
  print("Hello, man")
greetPerson()
# Out:
# Hello, man

# %%
def greetPerson():
  greeting = "Hello, man"
  return greeting
greetPerson()
# Out:
# 'Hello, man'

# %%
def greetPerson(name):
  greeting = f"Hello {name}"
  return greeting
greetPerson(name='Sabina')
# Out:
# 'Hello Sabina'
