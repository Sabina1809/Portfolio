# %%
print('Hello world')
# Out:
# Hello world

# %%
from os import name
name ='Sabina'

# %%
car = 'Tesla'

# %%
favoriteFruit = 'grape'
favorite_fruit = 'grape'

# %%
print(favoriteFruit)
# Out:
# grape

# %%
a = 15
b = 2
c = a % b
print (c)
# Out:
# 1

# %%
a = 15
b = 2
c = a/b
print (c)
# Out:
# 7.5

# %%
a = 5
b = 3
c = a + b
print (c)
# Out:
# 8

# %%
int_num = 15
print(float(int_num))
# Out:
# 15.0

# %%
int_num = 15
print(str(int_num))
# Out:
# 15

# %%
float_num = 15.35
print(int(float_num))
# Out:
# 15

# %%
print(type(float_num))
# Out:
# <class 'float'>

# %%
favoriteFlavor = input('what is your favorite flavor')
print(favoriteFlavor)
# Out:
# what is your favorite flavorMatcha
# Matcha

# %%
fist_c = 100 > 100 # False
second_c = 10 > 100 # False
print(fist_c and second_c) # False
# Out:
# False

# %%
favoriteColor = 'Sky Blue'
print(f"Your favorite color is {favoriteColor}")
# Out:
# Your favorite color is Sky Blue
