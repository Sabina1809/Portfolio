# %%
x = 10
def modify_global():
  global x
  x = x + 5
modify_global()
print(x)
# Out:
# 15

# %%
def studentsList(*students):
  for student in students:
    print(student)
studentsList('Sabina','Malika','Ziyoda','Odina')
# Out:
# Sabina
# Malika
# Ziyoda
# Odina

# %%
def describe_person(**kwargs):
  for key,value in kwargs.items():
    print(f"{key}:{value}")
describe_person(name="Alice")
# Out:
# name:Alice

# %%
from types import SimpleNamespace

student1 = SimpleNamespace(name='Sabina',age=20,major='Computer Science')

print(student1)
# Out:
# namespace(name='Sabina', age=20, major='Computer Science')

# %%
from types import SimpleNamespace

student1 = SimpleNamespace(name='Sabina',age=20,major='Computer Science')

print(student1.name)
# Out:
# Sabina

# %%
from types import SimpleNamespace

student1 = SimpleNamespace(name='Sabina',age=20,major='Computer Science')

print(student1.age)
# Out:
# 20

# %%
from types import SimpleNamespace

student1 = SimpleNamespace(name='Sabina',age=20,major='Computer Science')

print(student1.major)
# Out:
# Computer Science

# %%
from dataclasses import make_dataclass

Student = make_dataclass('Student', ['name', 'age', 'major'])

student1 = Student(name='Sabina', age=20, major='Computer Science')

print(student1)
# Out:
# Student(name='Sabina', age=20, major='Computer Science')

# %%
class Student():
    pass

student1 = Student()


student1.name = 'Sabina'
student1.age = 20

print(f"Name: {student1.name}, Age: {student1.age}")
# Out:
# Name: Sabina, Age: 20

# %%
class Student(object):
    def __init__(self, name, age):
        self.name = name
        self.age = age

student1 = Student('Sabina', 20)
student2 = Student('Malika', 21)

print(student1.name, student1.age)
# Out:
# Sabina 20

# %%
class Student(object):
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def sayHi(self):
      print(f'Salom{self.name}.Tanishganimdan xursandman')

student1 = Student('Sabina', 20)
student2 = Student('Malika', 21)

print(student1.name, student1.age)
student2.sayHi()
# Out:
# Sabina 20
# SalomMalika.Tanishganimdan xursandman

# %%
class BankAccount(object):
    def __init__(self, name, balance):
        self.owner = name
        self.balance = balance

account1 = BankAccount('Sabina', 1000)

print(account1.owner)
print(account1.balance)
# Out:
# Sabina
# 1000

# %%
class Student(object):
    graduation_year = 2025

    def __init__(self, name, age):
        self.name = name
        self.age = age

student1 = Student('Sabina', 20)
student2 = Student('Malika', 21)

print(student1.graduation_year)
print(student2.graduation_year)
# Out:
# 2025
# 2025

# %%
class Student(object):
    graduation_year = 2025
    count = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        Student.count += 1

    @classmethod
    def getCount(cls):
        print(f"Jami o'quvchilar soni: {cls.count}")

student1 = Student('Sabina', 20)
student2 = Student('Malika', 21)

print(student1.graduation_year)
print(student2.graduation_year)

Student.getCount()
# Out:
# 2025
# 2025
# Jami o'quvchilar soni: 2
