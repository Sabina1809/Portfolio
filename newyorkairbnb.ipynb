# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/new-york-city-airbnb-open-data/AB_NYC_2019.csv
# /kaggle/input/new-york-city-airbnb-open-data/New_York_City_.png

# %%
df = pd.read_csv('/kaggle/input/new-york-city-airbnb-open-data/AB_NYC_2019.csv')
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# id                              48895.0  1.901714e+07  1.098311e+07
# host_id                         48895.0  6.762001e+07  7.861097e+07
# latitude                        48895.0  4.072895e+01  5.453008e-02
# longitude                       48895.0 -7.395217e+01  4.615674e-02
# price                           48895.0  1.527207e+02  2.401542e+02
# minimum_nights                  48895.0  7.029962e+00  2.051055e+01
# number_of_reviews               48895.0  2.327447e+01  4.455058e+01
# reviews_per_month               38843.0  1.373221e+00  1.680442e+00
# calculated_host_listings_count  48895.0  7.143982e+00  3.295252e+01
# availability_365                48895.0  1.127813e+02  1.316223e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  9.471945e+06  1.967728e+07
# host_id                         2438.00000  7.822033e+06  3.079382e+07
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df['reviews_per_month'] = df['reviews_per_month'].fillna(df['reviews_per_month'].mean())

# %%
df.isna().mean()
# Out:
# id                                0.000000
# name                              0.000327
# host_id                           0.000000
# host_name                         0.000429
# neighbourhood_group               0.000000
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# price                             0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# last_review                       0.205583
# reviews_per_month                 0.205583
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# dtype: float64

# %%
df['name'] = df['name']. fillna(df['name'].mode()[0])

# %%
df['host_name'] = df['host_name'].fillna(df['name'].mode()[0])

# %%
df['last_review'] = df['last_review'].fillna(df['last_review'].mode()[0])

# %%
df.rename(columns={"id":"ID"}, inplace=True)
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#              ID                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df['name'] = df ['name'].apply(lambda x:1 if x == 'True'else 0)

# %%
plt.scatter(df['latitude'], df['longitude'])
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.show()

# %%
plt.plot(df['latitude'], df['longitude'])
plt.show()

# %%
#plt.bar(df['room_type'],df['price'])
#plt.show()

sns.barplot(x='room_type', y='price', data=df)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
plt.hist(df['availability_365'])
plt.title('Analysis of avialability')
plt.show()

# %%
room_counts = df['room_type']. value_counts()
plt.pie(room_counts, labels=room_counts.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7e4d795f1450>,
# ...
#  [Text(-0.06791271159741047, 1.0979015728213013, 'Entire home/apt'),
#   Text(-0.014029046165556239, -1.0999105353908039, 'Private room'),
#   Text(1.096946139126023, -0.08190951017135857, 'Shared room')],
#  [Text(-0.037043297234951165, 0.5988554033570733, '52.0%'),
#   Text(-0.00765220699939431, -0.5999512011222565, '45.7%'),
#   Text(0.5983342577051034, -0.04467791463892285, '2.4%')])

# %%
df['room_type']. value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
room_counts = df['room_type']. value_counts()
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.show()

# %%
sns.scatterplot(x='latitude', y='longitude', data=df)  

plt.show()

# %%
sns.boxplot(x='availability_365', y='room_type', data=df)
# Out:
# <Axes: xlabel='availability_365', ylabel='room_type'>

# %%
from sklearn.preprocessing import LabelEncoder as le

df['name'] = le().fit_transform(df['name'])
df['host_name'] = le().fit_transform(df['host_name'])
df['neighbourhood_group'] = le().fit_transform(df['neighbourhood_group'])
df['neighbourhood'] = le().fit_transform(df['neighbourhood'])
df['room_type'] = le().fit_transform(df['room_type'])


df
# Out:
#              ID  name   host_id  host_name  neighbourhood_group  \
# 0          2539     0      2787       4990                    1
# 1          2595     0      2845       4786                    2
# 2          3647     0      4632       2910                    2
# 3          3831     0      4869       6204                    1
# 4          5022     0      7192       5924                    2
# ...         ...   ...       ...        ...                  ...
# 48890  36484665     0   8232441       9052                    1
# 48891  36485057     0   6570630       6777                    1
# 48892  36485431     0  23492952       4264                    2
# 48893  36485609     0  30985759      10191                    2
# 48894  36487245     0  68119814       1969                    2
#
#        neighbourhood  latitude  longitude  room_type  price  minimum_nights  \
# 0                108  40.64749  -73.97237          1    149               1
# ...

# %%
education_order = {"Bachelor":1,"Master":2,"Phd":3}
df['name'] = df['name'].map(education_order)

# %%
from sklearn.preprossing import StandardScaler as scaler
from sklearn.preprossing import MinMaxScaler as scaler

df['name'] = scaler.fit_transform(df['name']])

# %%
df.corrwith(df['price']).abs().sort_values(ascending=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# price                             1.000000
# room_type                         0.249350
# longitude                         0.150019
# availability_365                  0.081829
# neighbourhood                     0.062057
# calculated_host_listings_count    0.057472
# number_of_reviews                 0.047954
# neighbourhood_group               0.044246
# minimum_nights                    0.042799
# ...

# %%
corr_matrix = df.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_0e5c8_row0_col0, #T_0e5c8_row2_col2, #T_0e5c8_row3_col3, #T_0e5c8_row4_col4, #T_0e5c8_row5_col5, #T_0e5c8_row6_col6, #T_0e5c8_row7_col7, #T_0e5c8_row8_col8, #T_0e5c8_row9_col9, #T_0e5c8_row10_col10, #T_0e5c8_row11_col11, #T_0e5c8_row12_col12, #T_0e5c8_row13_col13, #T_0e5c8_row14_col14, #T_0e5c8_row15_col15, #T_0e5c8_row16_col16, #T_0e5c8_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...
